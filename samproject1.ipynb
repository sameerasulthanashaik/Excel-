# %% [markdown]
# <a href="https://colab.research.google.com/github/sameerasulthanashaik/Excel-/blob/main/samproject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas is used to convert data to DataFrame
#pandas is used for preprocessing of data
import pandas as pd

# %%
df=pd.read_excel("C:\\Users\\gmk48\\Downloads\\StudentPerformance.xlsx")

# %%
#it is used to know the top of 5 rows of the data
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
#it is display the bottom/last five rows of data
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2                 23
# 9996                                 5                 58
# 9997                                 5                 74
# 9998                                 0                 95
# 9999                                 1                 64

# %%
df.sample()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 3137              9               92                         No            9
#
#       Sample Question Papers Practiced  Performance Index
# 3137                                 6                 93

# %%
#it display the rows and columns
df.shape
# Out:
# (10000, 6)

# %%
#it display the statistical summaries
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df["Hours Studied"].mean()
# Out:
# np.float64(4.9929)

# %%
#it displays the total information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 468.9+ KB

# %%
#it is used to check whether it is having null values or not
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
#label encoder is used to transform the strings to numerical values
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df["Extracurricular Activities"]=label.fit_transform(df["Extracurricular Activities"])

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
#Standard scaler
#it is used when we have to calculates the distance
#it converts into the mean 0 and variance 1
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(3,3))
plt.scatter(df["Hours Studied"],df["Performance Index"],color="red", marker="+")
plt.title("Hours Stuudent vs Performance")
plt.xlabel("Hours")
plt.ylabel("Performance")
plt.grid()
plt.show()

# %%
x=df[["Hours Studied","Previous Scores","Extracurricular Activities","Sleep Hours","Sample Question Papers Practiced"]]

# %%
y=df["Performance Index"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
df.shape
# Out:
# (10000, 6)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y
# Out:
# 0       91
# 1       65
# 2       45
# 3       36
# 4       66
#         ..
# 9995    23
# 9996    58
# 9997    74
# 9998    95
# 9999    64
# Name: Performance Index, Length: 10000, dtype: int64

# %%
y_pred
# Out:
# array([51.69936447, 35.432019  , 82.91206933, ..., 31.50292532,
#        46.57994193, 29.19002375], shape=(2000,))

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9886750113507796

# %%
df.dtypes
# Out:
# Hours Studied                       int64
# Previous Scores                     int64
# Extracurricular Activities          int64
# Sleep Hours                         int64
# Sample Question Papers Practiced    int64
# Performance Index                   int64
# dtype: object

# %%
new_data=[[
    5,
    78,
    5,
    8,
    7
]]

# %%
predicticion=model.predict(new_data)
# Out:
# e:\Users\gmk48\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(predicticion)
# Out:
# [67.82490291]
